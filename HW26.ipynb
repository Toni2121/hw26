# %%
import numpy as np
import pandas as pd

# %%
csv_df = pd.read_csv(r"hw_work.csv")
csv_df

#------------------------------
# 1.
print(csv_df.info())
# b. 20 columns
# c. 3333 rows
# d. Total day minutes
# e. memory usage: 520.9+ KB
print()
#------------------------------
# 2.
print(csv_df["Account length"].describe())
# b. Highest Value: 243.000000
# c. Smallest value: 1.000000
# d. Avg: 101.064806
# e. rows: 3333.000000
print()
#------------------------------
# 3.
print(csv_df.describe().transpose())
print()
#------------------------------
# 4.
print(csv_df.head(5))
print(csv_df.tail(5))
print()
#------------------------------
# 5.
print(csv_df["State"])
print()
#------------------------------
# 6.
print(csv_df[['State', 'International plan']])
print()
#------------------------------
# 7.
print(csv_df[csv_df['International plan'] == "Yes"])
print()
#------------------------------
# 8.
print(csv_df[(csv_df['International plan'] == "Yes") & (csv_df['Churn'] == True)])
print()
#------------------------------
# 9.
print(csv_df.iloc[14])
print()
#------------------------------
# 10.
print(csv_df.iloc[14:])
print()
#------------------------------
# 11.
csv_df.set_index('State', inplace=True)
print(csv_df.loc["LA"])
print()
#------------------------------
# 12.
csv_df.drop('Area code', axis=1, inplace=True)
print(csv_df)
print()
#------------------------------
# 13.
csv_df.reset_index(inplace=True)
csv_df.drop(3328, axis=0, inplace=True)
print(csv_df)
print()
#------------------------------
# 14.
csv_df['total_min'] = csv_df['Total night minutes'] + csv_df['Total intl minutes']
csv_df['avg total_min'] = (csv_df['Total night minutes'] + csv_df['Total intl minutes']) / 2
print(csv_df)
print()
#------------------------------
# 15.
pd_head = csv_df.head(1)
pd_tail = csv_df.tail(1)
new_df = pd.concat([pd_head, pd_tail])
new_df
print()
#------------------------------
# 16.
new_row = {
    'State': 'LA',
    'Account length': 150,
    'International plan': 'No',
    'Voice mail plan': 'Yes',
    'Number vmail messages': 20,
    'Total day minutes': 200.5,
    'Total day calls': 100,
    'Total day charge': 50.12,
    'Total eve minutes': 150.3,
    'Total eve calls': 90,
    'Total eve charge': 30.56,
    'Total night minutes': 170.4,
    'Total night calls': 80,
    'Total night charge': 25.34,
    'Total intl minutes': 12.2,
    'Total intl calls': 5,
    'Total intl charge': 3.29,
    'Customer service calls': 1,
    'Churn': False,
    'total_min': 182.6,
    'avg total_min': 91.3
}

new_row_df = pd.DataFrame([new_row])
new_df = pd.concat([new_df, new_row_df], ignore_index=True)
new_df
print()
#------------------------------
# 17.
# The inplace parameter determines whether the operation modifies the existing DataFrame directly or returns a new one
#------------------------------
# 18.
# a culumn in a table cannout be both an index and a column
#------------------------------
# 19. 
# axis 1 = for columns
# axis 0 = for rows
#------------------------------
# 20.
# & = and
# | = or
# ~ =
# Isin = checks if the values in a column are in a specified list, set, or another Series
# between =  to filter data within a range
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3323 non-null   float64
#  7   Total day calls         3323 non-null   float64
#  8   Total day charge        3315 non-null   float64
#  9   Total eve minutes       3324 non-null   float64
#  10  Total eve calls         3325 non-null   float64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3332 non-null   float64
# ...

# %%
csv_df = pd.read_csv(r"hw_work.csv")
csv_df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...
